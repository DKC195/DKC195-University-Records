# %% [markdown]
# Assignment 01
#
# Dhiraj KC

# %% [markdown]
# Part A

# %%
inp ="dhiraj"
out=inp.capitalize() #Makes first character uppercase and rest lowercase.
print(out)

# %%
inp ="KC"
out=inp.center(8,'a') #Brings string to the center of n length width.
print(out)

# %%
inp ="I want lock down to be over"
out=inp.endswith("want",2,6) #Test whether a string is on spicific position or not.
out2=inp.endswith("want",3,5)
print(out)
print(out2)

# %%
inp ="I like to code."
out=inp.find("o",9,15) #Find location of particular string on the string. Returns -1 if not found.
print(out)

# %%
inp ="I live in {loc}"
add=input("Where do you live?: ") #Fill in the blanks.
out=inp.format(loc=add)
print(out)

# %%
inp ="I study at Purwanchal Campus, Dharan."
out=inp.index("at", 5 ,10) #Same as Find but gives error if not found.
print(out)

# %%
inp ="lifesuckshahahaha"
out=inp.isalpha() #Check whether all strings are Alphabet or not.
print(out)
inp ="I want lock down to be over"
out=inp.isalpha()
print(out)

# %%
inp ="oh my god!"
out=inp.isidentifier() #Checks whwther the string is identifier or not.
print(out)
inp="input"
out=inp.isidentifier()
print(out)

# %%
inp ="really"
out=inp.islower() #Checks if string is lowercase or not.
print(out)
inp ="Really"
out=inp.islower()
print(out)

# %%
inp ="NOPE"
out=inp.isupper() #Checks if string is Uppercase or not.
print(out)
inp ="Nope"
out=inp.isupper()
print(out)

# %%
inp ="I watched Loki yesterday"
out=inp.rfind('e') #Find in reverse
print(out)

# %%
inp ="It was great and had a cliffhanger"
out=inp.rindex('e') #Index in reverse 
print(out)

# %%
inp ="Hello"
out=inp.rjust(8,'r') #Adds missing letters from right.
print(out)

# %%
inp ="I want lock down to be over"
out=inp.split() #Creates list from string with space as comma.
print(out)

# %%
inp ="really"
out=inp.upper() #Converts Lowercase into uppercase.
print(out)

# %% [markdown]
# Part B

# %%
lst=["Dhiraj", "Bibek", "Pawan", "Akil", "Jharana", "Pranab", "Sabin"]
lst.append("Sudip") #Adds Element to the list.
print(lst)

# %%
lst=["Dhiraj", "Bibek", "Pawan", "Akil", "Jharana", "Pranab", "Sabin"]
lst.clear() #Removes everything from list.
print(lst)

# %%
lst=["Dhiraj", "Bibek", "Pawan", "Akil", "Jharana", "Pranab", "Sabin"]
lst.count("Akil") #Counts no.of {sth} in list.

# %%
lst=["Dhiraj", "Bibek", "Pawan", "Akil", "Jharana", "Pranab", "Sabin"]
lst.index("Akil") #Gives position of {sth} in list.

# %%
lst=["Dhiraj", "Bibek", "Pawan", "Akil", "Jharana", "Pranab", "Sabin"]
lst.pop(5) #Gives {n}th term of list.

# %%
lst=["Dhiraj", "Bibek", "Pawan", "Akil", "Jharana", "Pranab", "Sabin"]
lst.remove("Sabin") #Removes {sth} from list.
print(lst)

# %%
lst=["Dhiraj", "Bibek", "Pawan", "Akil", "Jharana", "Pranab", "Sabin"]
lst.reverse() #Reverse Order of list.
print(lst)

# %%
lst=["Dhiraj", "Bibek", "Pawan", "Akil", "Jharana", "Pranab", "Sabin"]
lst.sort() #Sorts in ASCII Order.
print(lst)
