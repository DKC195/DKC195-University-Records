# %% [markdown]
# Q01

# %%
str_x=list(input('Enter a string: '))
str_x.reverse()
print(''.join(str_x))

# %% [markdown]
# Q02

# %%
str_x=input('Enter the string: ')
str_x=str_x.replace(' ', '')
str_y=list(str_x)
str_z=list(str_x.upper())
u=0
l=0
for i in range(len(str_x)):
  if str_y[i]==str_z[i]:
    u+=1
  else:
    l+=1
print('There are', u,'upper cases and', l,'lower cases.')

# %% [markdown]
# Q03

# %%
a=[] 
for i in range(int(input("Enter the no of inputs: "))):
  b=input("Enter a String: ")
  a.append(b)
  a.reverse()
  while (a.count(b)!=1):
    a.remove(b)
  a.reverse()h
print(a)

# %% [markdown]
# Q04

# %%
year=int(input("Enter the Year: "))
month=int(input("Enter the Month: "))
day=int(input("Enter the Day: "))
inp=input("Enter AD or BS: ")
if inp.lower()=="ad":
  out="BS"
  day+=16
  if day>30:
    month+=1
    day-=30
  month+=5
  if month>12:
    year+=1
    month-=12
  year+=56
elif inp.lower()=="bs":
  out="AD"
  if day<16:
    day+=14
    month-=1
  else:
    day-=16
  if month<5: 
    month+=7
    year-=1
  else:
    month-=5
  year-=56
else:
  print("Do you know how to type?")
print("                  DD MM YY")
print(f"The date in {inp} is {day}/{month}/{year}{out}")
